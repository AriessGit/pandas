# %%
import pandas as pd
import numpy as np
from IPython.display import display

# %%
df = pd.read_csv("mpg.csv")
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
# 1. Sorting 🔢

# Q1.1 Sort the DataFrame by mpg in ascending order
display('DataFrame by mpg in ascending order', df.sort_values(by = 'mpg',ascending = True).head(5))

# Q1.2 Sort the DataFrame by weight in descending order
display('DataFrame by weight in descending order', df.sort_values('weight', ascending = False).head(5))

# Q1.3 Sort by model_year first, then by mpg within each year
display('Sort by model_year first, then by mpg within each year',df.sort_values(['model_year', 'mpg']))
# Out:
# 'DataFrame by mpg in ascending order'
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 28    9.0          8         304.0        193    4732          18.5
# 25   10.0          8         360.0        215    4615          14.0
# 26   10.0          8         307.0        200    4376          15.0
# 103  11.0          8         400.0        150    4997          14.0
# 67   11.0          8         429.0        208    4633          11.0
#
#      model_year  origin              name
# 28           70       1          hi 1200d
# 25           70       1         ford f250
# 26           70       1         chevy c20
# 103          73       1  chevrolet impala
# 67           72       1   mercury marquis
# 'DataFrame by weight in descending order'
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 44   13.0          8         400.0        175    5140          12.0
# 103  11.0          8         400.0        150    4997          14.0
# ...

# %%
# Value Counts 📊

df = pd.read_csv("mpg.csv")

# Q2.1 Find how many cars of each cylinder type exist
display(df.value_counts('cylinders', ascending = True).to_frame())
print()
# for practice, I've written another commands: 
display(df['cylinders'].value_counts().to_frame()) # Ascending = False -- maximum  goe's at first
print()
display(df['cylinders'].value_counts().sort_index()) # sorted by index 
print()

# Q2.2 Count how many times each origin appears
display(df['origin'].value_counts().sort_index())
print()
# Q2.3 Which model_year has the most cars?
display(df['model_year'].value_counts().head(1))
# Out:
#            count
# cylinders
# 5              3
# 3              4
# 6             84
# 8            103
# 4            204
#            count
# cylinders
# 4            204
# 8            103
# 6             84
# 3              4
# 5              3
# cylinders
# 3      4
# 4    204
# 5      3
# 6     84
# 8    103
# Name: count, dtype: int64
# origin
# 1    249
# 2     70
# 3     79
# Name: count, dtype: int64
# model_year
# 73    40
# Name: count, dtype: int64

# %%
#GroupBy & Aggregations 🧮
# Q3.1 Group by cylinders and calculate the average mpg
display(df.groupby(by = 'cylinders').mean('mpg'))

# Q3.2 Group by origin and find the maximum horsepower
display(df.groupby(by = 'origin').max('horspower'))

# Q3.3 Group by model_year and calculate both the mean and median of weight
display(df.groupby(by = 'model_year')['weight'].agg(['mean', 'median']))
# Out:
#                  mpg  displacement       weight  acceleration  model_year  \
# cylinders
# 3          20.550000     72.500000  2398.500000     13.250000   75.500000
# 4          29.286765    109.796569  2308.127451     16.601471   77.073529
# 5          27.366667    145.000000  3103.333333     18.633333   79.000000
# 6          19.985714    218.142857  3198.226190     16.263095   75.928571
# 8          14.963107    345.009709  4114.718447     12.955340   73.902913
#
#              origin
# cylinders
# 3          3.000000
# 4          1.985294
# 5          2.000000
# 6          1.190476
# 8          1.000000
#          mpg  cylinders  displacement  weight  acceleration  model_year
# origin
# 1       39.0          8         455.0    5140          22.2          82
# 2       44.3          6         183.0    3820          24.8          82
# 3       46.6          6         168.0    2930          21.0          82
#                    mean  median
# model_year
# ...

# %%
#4. Unique & nunique 🎯
# Q4.1 How many unique car names are in the dataset?
display(df['name'].nunique())
print()

# Q4.2 List all unique values in the cylinders column
print(df['cylinders'].unique())
print()

# Q4.3 How many unique model_year values are there?
display(df['model_year'].nunique())
# Out:
# 305
# [8 4 6 3 5]
# 13
